# %% [markdown]
# # VnV (ver. 3)
#
# - by JPark
# - 모델 추가
# - 지연 시간 측정을 위한 코드 통합

# %%
#------------------------------------------------------
# Config
#------------------------------------------------------

# Test images

zip_images_url = 'http://keticmr.iptime.org:22080/edgeai/images/imagenet-mini-val.zip'
zip_images = 'imagenet-mini-val.zip'
dataset_root = './dataset'
fpath_zip_images = dataset_root + '/' + zip_images
fpath_testimages = dataset_root + '/imagenet-mini-val/'

# Models
urlroot = 'http://keticmr.iptime.org:22080/edgeai/models_jpark/'
modeldir = './checkpoint/'
    
model_names_resnet = [ 
    'resnet18',
    'resnet34',
    'resnet50',
    'resnet101',
    'resnet152',
]
repo_resnet = 'pytorch/vision:v0.10.0'

model_names_mobnet = [
    'mobilenet_v3_small',
    'mobilenet_v3_large',
]
repo_mobnet = 'pytorch/vision:v0.10.0'

'''
model_names_effnet = [ 
    'nvidia_efficientnet_b0',
    'nvidia_efficientnet_b4',
    'nvidia_efficientnet_widese_b0',
    'nvidia_efficientnet_widese_b4',
]
repo_effnet = 'NVIDIA/DeepLearningExamples:torchhub'
'''

from efficientnet_pytorch import EfficientNet
model_names_effnet = [ 
    'efficientnet-b0',
    'efficientnet-b1',
    'efficientnet-b2',
    'efficientnet-b3',
    'efficientnet-b4',
    'efficientnet-b5',
    'efficientnet-b6',
    'efficientnet-b7',
]
repo_effnet = ''



model_names = model_names_resnet + model_names_effnet + model_names_mobnet
#model_names = model_names_effnet


pth_names = [ model_name + '-dict.pth' for model_name in model_names ]

urlmodels = []
for pth_name in pth_names:
    urlmodels.append(urlroot + pth_name)

model_fpaths = []
for pth_name in pth_names:
    model_fpaths.append(modeldir + pth_name)

# %%
pth_names
# Out:
# ['resnet18-dict.pth',
#  'resnet34-dict.pth',
#  'resnet50-dict.pth',
#  'resnet101-dict.pth',
#  'resnet152-dict.pth',
#  'efficientnet-b0-dict.pth',
#  'efficientnet-b1-dict.pth',
#  'efficientnet-b2-dict.pth',
#  'efficientnet-b3-dict.pth',
#  'efficientnet-b4-dict.pth',
#  'efficientnet-b5-dict.pth',
#  'efficientnet-b6-dict.pth',
#  'efficientnet-b7-dict.pth',
#  'mobilenet_v3_small-dict.pth',
#  'mobilenet_v3_large-dict.pth']

# %%
urlmodels
# Out:
# ['http://keticmr.iptime.org:22080/edgeai/models_jpark/resnet18-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/resnet34-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/resnet50-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/resnet101-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/resnet152-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b0-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b1-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b2-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b3-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b4-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b5-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b6-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/efficientnet-b7-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/mobilenet_v3_small-dict.pth',
#  'http://keticmr.iptime.org:22080/edgeai/models_jpark/mobilenet_v3_large-dict.pth']

# %%
model_fpaths
# Out:
# ['./checkpoint/resnet18-dict.pth',
#  './checkpoint/resnet34-dict.pth',
#  './checkpoint/resnet50-dict.pth',
#  './checkpoint/resnet101-dict.pth',
#  './checkpoint/resnet152-dict.pth',
#  './checkpoint/efficientnet-b0-dict.pth',
#  './checkpoint/efficientnet-b1-dict.pth',
#  './checkpoint/efficientnet-b2-dict.pth',
#  './checkpoint/efficientnet-b3-dict.pth',
#  './checkpoint/efficientnet-b4-dict.pth',
#  './checkpoint/efficientnet-b5-dict.pth',
#  './checkpoint/efficientnet-b6-dict.pth',
#  './checkpoint/efficientnet-b7-dict.pth',
#  './checkpoint/mobilenet_v3_small-dict.pth',
#  './checkpoint/mobilenet_v3_large-dict.pth']

# %%
fpath_zip_images
# Out:
# './dataset/imagenet-mini-val.zip'

# %%
model_names
# Out:
# ['resnet18',
#  'resnet34',
#  'resnet50',
#  'resnet101',
#  'resnet152',
#  'efficientnet-b0',
#  'efficientnet-b1',
#  'efficientnet-b2',
#  'efficientnet-b3',
#  'efficientnet-b4',
#  'efficientnet-b5',
#  'efficientnet-b6',
#  'efficientnet-b7',
#  'mobilenet_v3_small',
#  'mobilenet_v3_large']

# %% [markdown]
# ## 00. 사전작업
#
# - 사전으로 실험을 위한 디렉토리를 생성하고, 추론 영상을 다운로드 받습니다. (변인통제 요소)

# %%
#------------------------------------------------------
# Download data
#------------------------------------------------------
import os
import urllib

# make download directory
def makedir(path): 
    isdir = os.path.isdir(path)
    
    try: 
        os.makedirs(path)
    except OSError: 
        if not isdir: 
            raise
    return os.path.abspath(path), isdir

# Download images
d, isdir = makedir(dataset_root) # 저장 공간 생성

if isdir:
    url, fname = (zip_images_url, fpath_zip_images)
    isfile_exist = os.path.exists(os.path.join(os.getcwd(), fname))
    
    print('downloading...')
    if not isfile_exist:
        try: 
            urllib.URLopener().retrieve(url, fname)
        except: 
            urllib.request.urlretrieve(url, fname)
        print('[+] download completed.')
        # Unzip
        cmd = 'unzip ' + fpath_zip_images + ' -d ' + dataset_root
        print(cmd)
        os.system(cmd)
    else:
        print('[+] download skipped ')


from glob import iglob

'''
# read test files
testfiles = []
for fname in sorted( iglob(fpath_testimages + '**/*.JPEG', recursive=True) ):
    testfiles.append(fname)
'''

idx_gt = []
idx = 0
testfiles = []
for d in sorted( iglob(fpath_testimages + 'n*', recursive=False) ):
    for fname in sorted( iglob(d + '/*.JPEG', recursive=True) ):
        testfiles.append(fname)
        idx_gt.append( idx )
    idx += 1


# Read the categories
with open("imagenet_classes.txt", "r") as f:
    categories = [s.strip() for s in f.readlines()]

# %% [markdown]
# ## 01. 실행

# %%
len(idx_gt)
# Out:
# 0

# %% [markdown]
# ## GPU 동작모드

# %%
i=4
print (f'{i:04d}')
# Out:
# 0004

# %%
# sample execution (requires torchvision)
from PIL import Image
from torchvision import transforms
import time
from tqdm import tqdm
import numpy as np
import torch

'''
# Define transforms for the evaluation phase
preprocess = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                ])
'''

preproc = ['method1', 'method2']
preproc_method = 'method1'

#devices = ['cuda', 'cpu']
devices = ['cuda']

models = []

testset = testfiles[:]
n = len(testset)

# 디바이스별 반복
for device in devices: 
    print('-'*50)
    print('device = ', device, flush=True)
    print('-'*50)
        
    # 모델별 반복
    for model_idx, model_name in enumerate(model_names):
        start = time.time() # strt timer        
        print(f'model = {model_names[model_idx]}', flush=True)
        
        # 모델 템플릿 다운로드 (from torch.hub)
        if model_name in model_names_resnet:
            model = torch.hub.load(repo_resnet, model_name, pretrained=False)
        elif model_name in model_names_mobnet:
            model = torch.hub.load(repo_mobnet, model_name, pretrained=False)
        elif model_name in model_names_effnet:
            #model = torch.hub.load(repo_effnet, model_name, pretrained=False)
            model = EfficientNet.from_pretrained(model_name)
        else:
            pass
    
        # 모델 가중치 다운로드 (from AI 모델 리포지토리)
        if False:    
            # 방법 1
            pass
        
            # torch.hub.download_url_to_file(urlroot+pthnames[model_idx], modeldir+pthnames[model_idx])
            # model.load_state_dict(torch.hub.load_state_dict_from_url(checkpoint, progress=False))
            # model.eval()
        else:
            # 방법 2
            checkpoint = urlmodels[model_idx]
            model.load_state_dict(torch.hub.load_state_dict_from_url(checkpoint, progress=False))
            model.eval().to(device) # change model to evauation mode (e.g. disable Dropout, BatchNorm)
            models.append(model)
 
        # 시험용 입력 영상
        top1_cnt = 0
        top5_cnt = 0
        top1_catids = []
              
        # 시험용 입력 영상 전처리 (크기 및 컬러채널)
        if preproc_method == preproc[0]:
            preprocess = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
            ])
        else:
            preprocess = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ])

        # 시험영상별 반복
        imgidx = 0
        for fpath in tqdm( testset ):
        #for fpath in testset:
            #print( fpath )
            input_image = Image.open(fpath)

            try:
                input_tensor = preprocess(input_image)
            except:
                # gray scale to color
                input_image = Image.open(fpath).convert("RGB")
                input_tensor = preprocess(input_image)

            input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

            # 디바이스 설정
            if device == 'cuda':
                if torch.cuda.is_available():
                    input_batch = input_batch.to('cuda')
                    model.to('cuda')
            else:
                input_batch = input_batch.to('cpu')
                model.to('cpu')
              
            with torch.no_grad():
                output = model(input_batch)

            # Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
            #print(output[0])

            # The output has unnormalized scores. To get probabilities, you can run a softmax on it.
            probabilities = torch.nn.functional.softmax(output[0], dim=0)
            #print(probabilities)

            # Show top categories per image
            top5_prob, top5_catid = torch.topk(probabilities, 5)
            for i in range(top5_prob.size(0)):
                #print(top5_catid[i])
                #print(imgidx, ' ', categories[top5_catid[i]], top5_prob[i].item())

                if( top5_catid[i] == idx_gt[imgidx] ):
                    top5_cnt += 1
                    
            # Show top categories per image
            top1_prob, top1_catid = torch.topk(probabilities, 1)
            top1_catids.append(top1_catid[0])
            if( top1_catid[0] == idx_gt[imgidx] ):
                top1_cnt += 1
 
            imgidx += 1

        end = time.time() # end timer
        print('n = ', n)
        print('top1_cnt = ', top1_cnt)
        print('top1_acc = ', top1_cnt/n)
        print('top5_cnt = ', top5_cnt)
        print('top5_acc = ', top5_cnt/n)
        print('time = ', end - start)
        print('')
        
        
        print('-' * 70)
        print('GT')
        print('-' * 70)
        for idx, cid in enumerate(idx_gt):
            print(f'{idx:04d} = {cid}')
            
        print('-' * 70)
        print('Top1 category IDs')
        print('-' * 70)
        for idx, cid in enumerate(top1_catids):
            print(f'{idx:04d} = {int(cid)}')
# Out:
# --------------------------------------------------
# device =  cuda
# --------------------------------------------------
# model = resnet18
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jpark/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /home/jpark/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 3923/3923 [00:39<00:00, 99.81it/s]
# n =  3923
# top1_cnt =  2500
# top1_acc =  0.637267397399949
# top5_cnt =  3358
# top5_acc =  0.8559775681876115
# time =  40.883331298828125
#
# ----------------------------------------------------------------------
# GT
# ----------------------------------------------------------------------
# 0000 = 0
# 0001 = 0
# 0002 = 0
# 0003 = 1
# 0004 = 1
# 0005 = 1
# 0006 = 2
# 0007 = 2
# 0008 = 2
# 0009 = 2
# 0010 = 2
# 0011 = 3
# 0012 = 3
# 0013 = 3
# 0014 = 4
# 0015 = 4
# 0016 = 4
# 0017 = 4
# 0018 = 4
# 0019 = 5
# 0020 = 5
# 0021 = 5
# 0022 = 6
# 0023 = 6
# 0024 = 6
# 0025 = 7
# 0026 = 7
# 0027 = 7
# 0028 = 8
# 0029 = 8
# 0030 = 8
# 0031 = 9
# 0032 = 9
# 0033 = 9
# 0034 = 10
# 0035 = 10
# 0036 = 10
# 0037 = 10
# 0038 = 11
# 0039 = 11
# 0040 = 11
# 0041 = 11
# 0042 = 12
# 0043 = 12
# 0044 = 12
# 0045 = 13
# 0046 = 13
# 0047 = 13
# 0048 = 13
# 0049 = 14
# 0050 = 14
# 0051 = 14
# 0052 = 14
# 0053 = 15
# 0054 = 15
# 0055 = 15
# 0056 = 16
# 0057 = 16
# 0058 = 16
# 0059 = 17
# 0060 = 17
# 0061 = 17
# 0062 = 18
# 0063 = 18
# 0064 = 19
# 0065 = 19
# 0066 = 19
# 0067 = 19
# 0068 = 20
# 0069 = 20
# 0070 = 20
# 0071 = 21
# 0072 = 21
# 0073 = 21
# 0074 = 21
# 0075 = 22
# 0076 = 22
# 0077 = 22
# 0078 = 23
# 0079 = 23
# 0080 = 23
# 0081 = 24
# 0082 = 24
# 0083 = 24
# 0084 = 24
# 0085 = 25
# 0086 = 25
# 0087 = 25
# 0088 = 26
# 0089 = 26
# 0090 = 26
# 0091 = 26
# 0092 = 27
# 0093 = 27
# 0094 = 27
# 0095 = 27
# 0096 = 28
# 0097 = 28
# 0098 = 28
# 0099 = 28
# 0100 = 29
# 0101 = 29
# 0102 = 30
# 0103 = 30
# 0104 = 30
# 0105 = 31
# 0106 = 31
# 0107 = 31
# 0108 = 31
# 0109 = 32
# 0110 = 32
# 0111 = 32
# 0112 = 32
# 0113 = 32
# 0114 = 33
# 0115 = 33
# 0116 = 33
# 0117 = 34
# 0118 = 34
# 0119 = 34
# 0120 = 35
# 0121 = 35
# 0122 = 35
# 0123 = 35
# 0124 = 36
# 0125 = 36
# 0126 = 36
# 0127 = 36
# 0128 = 37
# 0129 = 37
# 0130 = 38
# 0131 = 38
# 0132 = 38
# 0133 = 38
# 0134 = 39
# 0135 = 39
# 0136 = 39
# 0137 = 40
# 0138 = 40
# 0139 = 40
# 0140 = 40
# 0141 = 41
# 0142 = 41
# 0143 = 41
# 0144 = 42
# 0145 = 42
# 0146 = 42
# 0147 = 42
# 0148 = 43
# 0149 = 43
# 0150 = 43
# 0151 = 44
# 0152 = 44
# 0153 = 44
# 0154 = 45
# 0155 = 45
# 0156 = 45
# 0157 = 46
# 0158 = 46
# 0159 = 47
# 0160 = 47
# 0161 = 47
# 0162 = 47
# 0163 = 48
# 0164 = 48
# 0165 = 48
# 0166 = 49
# 0167 = 49
# 0168 = 49
# 0169 = 50
# 0170 = 50
# 0171 = 50
# 0172 = 51
# 0173 = 51
# 0174 = 51
# 0175 = 51
# 0176 = 52
# 0177 = 52
# 0178 = 52
# 0179 = 52
# 0180 = 53
# 0181 = 53
# 0182 = 53
# 0183 = 53
# 0184 = 54
# 0185 = 54
# 0186 = 54
# 0187 = 54
# 0188 = 55
# 0189 = 55
# 0190 = 55
# 0191 = 56
# 0192 = 56
# 0193 = 56
# 0194 = 57
# 0195 = 57
# 0196 = 58
# 0197 = 58
# 0198 = 58
# 0199 = 59
# 0200 = 59
# 0201 = 59
# 0202 = 60
# 0203 = 60
# 0204 = 60
# 0205 = 60
# 0206 = 61
# 0207 = 61
# 0208 = 61
# 0209 = 61
# 0210 = 62
# 0211 = 62
# 0212 = 62
# 0213 = 62
# 0214 = 63
# 0215 = 63
# 0216 = 63
# 0217 = 63
# 0218 = 63
# 0219 = 64
# 0220 = 64
# 0221 = 64
# 0222 = 64
# 0223 = 65
# 0224 = 65
# 0225 = 65
# 0226 = 66
# 0227 = 66
# 0228 = 66
# 0229 = 67
# 0230 = 67
# 0231 = 67
# 0232 = 68
# 0233 = 68
# 0234 = 68
# 0235 = 69
# 0236 = 69
# 0237 = 69
# 0238 = 69
# 0239 = 70
# 0240 = 70
# 0241 = 70
# 0242 = 70
# 0243 = 71
# 0244 = 72
# 3813 = 969
# 3814 = 969
# 3815 = 970
# 3816 = 970
# 3817 = 970
# 3818 = 971
# 3819 = 971
# 3820 = 971
# 3821 = 971
# 3822 = 972
# 3823 = 972
# 3824 = 972
# 3825 = 972
# 3826 = 973
# 3827 = 973
# 3828 = 974
# 3829 = 974
# 3830 = 974
# 3831 = 974
# 3832 = 975
# 3833 = 975
# 3834 = 975
# 3835 = 975
# 3836 = 976
# 3837 = 976
# 3838 = 976
# 3839 = 976
# 3840 = 977
# 3841 = 977
# 3842 = 977
# 3843 = 977
# 3844 = 978
# 3845 = 978
# 3846 = 978
# 3847 = 978
# 3848 = 979
# 3849 = 979
# 3850 = 979
# 3851 = 980
# 3852 = 980
# 3853 = 980
# 3854 = 980
# 3855 = 981
# 3856 = 981
# 3857 = 981
# 3858 = 982
# 3859 = 982
# 3860 = 982
# 3861 = 982
# 3862 = 983
# 3863 = 983
# 3864 = 983
# 3865 = 983
# 3866 = 984
# 3867 = 984
# 3868 = 984
# 3869 = 984
# 3870 = 984
# 3871 = 985
# 3872 = 985
# 3873 = 985
# 3874 = 985
# 3875 = 986
# 3876 = 986
# 3877 = 986
# 3878 = 986
# 3879 = 987
# 3880 = 987
# 3881 = 987
# 3882 = 988
# 3883 = 988
# 3884 = 988
# 3885 = 988
# 3886 = 989
# 3887 = 989
# 3888 = 989
# 3889 = 989
# 3890 = 990
# 3891 = 990
# 3892 = 990
# 3893 = 991
# 3894 = 991
# 3895 = 992
# 3896 = 992
# 3897 = 993
# 3898 = 993
# 3899 = 993
# 3900 = 994
# 3901 = 994
# 3902 = 994
# 3903 = 994
# 3904 = 995
# 3905 = 995
# 3906 = 995
# 3907 = 996
# 3908 = 996
# 3909 = 996
# 3910 = 997
# 3911 = 997
# 3912 = 997
# 3913 = 997
# 3914 = 997
# 3915 = 997
# 3916 = 998
# 3917 = 998
# 3918 = 999
# 3919 = 999
# 3920 = 999
# 3921 = 999
# 3922 = 999
# ----------------------------------------------------------------------
# Top1 category IDs
# ----------------------------------------------------------------------
# 0000 = tensor([0], device='cuda:0')
# 0001 = tensor([0], device='cuda:0')
# 0002 = tensor([0], device='cuda:0')
# 0003 = tensor([1], device='cuda:0')
# 0004 = tensor([669], device='cuda:0')
# 0005 = tensor([1], device='cuda:0')
# 0006 = tensor([2], device='cuda:0')
# 0007 = tensor([2], device='cuda:0')
# 0008 = tensor([2], device='cuda:0')
# 0009 = tensor([2], device='cuda:0')
# 0010 = tensor([2], device='cuda:0')
# 0011 = tensor([3], device='cuda:0')
# 0012 = tensor([6], device='cuda:0')
# 0013 = tensor([3], device='cuda:0')
# 0014 = tensor([428], device='cuda:0')
# 0015 = tensor([4], device='cuda:0')
# 0016 = tensor([4], device='cuda:0')
# 0017 = tensor([6], device='cuda:0')
# 0018 = tensor([4], device='cuda:0')
# 0019 = tensor([5], device='cuda:0')
# 0020 = tensor([6], device='cuda:0')
# 0021 = tensor([6], device='cuda:0')
# 0022 = tensor([6], device='cuda:0')
# 0023 = tensor([6], device='cuda:0')
# 0024 = tensor([6], device='cuda:0')
# 0025 = tensor([80], device='cuda:0')
# 0026 = tensor([7], device='cuda:0')
# 0027 = tensor([8], device='cuda:0')
# 0028 = tensor([8], device='cuda:0')
# 0029 = tensor([8], device='cuda:0')
# 0030 = tensor([8], device='cuda:0')
# 0031 = tensor([9], device='cuda:0')
# 0032 = tensor([386], device='cuda:0')
# 0033 = tensor([9], device='cuda:0')
# 0034 = tensor([13], device='cuda:0')
# 0035 = tensor([10], device='cuda:0')
# 0036 = tensor([13], device='cuda:0')
# 0037 = tensor([13], device='cuda:0')
# 0038 = tensor([11], device='cuda:0')
# 0039 = tensor([11], device='cuda:0')
# 0040 = tensor([11], device='cuda:0')
# 0041 = tensor([11], device='cuda:0')
# 0042 = tensor([13], device='cuda:0')
# 0043 = tensor([12], device='cuda:0')
# 0044 = tensor([12], device='cuda:0')
# 0045 = tensor([13], device='cuda:0')
# 0046 = tensor([13], device='cuda:0')
# 0047 = tensor([13], device='cuda:0')
# 0048 = tensor([13], device='cuda:0')
# 0049 = tensor([14], device='cuda:0')
# 0050 = tensor([14], device='cuda:0')
# 0051 = tensor([92], device='cuda:0')
# 0052 = tensor([14], device='cuda:0')
# 0053 = tensor([15], device='cuda:0')
# 0054 = tensor([133], device='cuda:0')
# 0055 = tensor([15], device='cuda:0')
# 0056 = tensor([16], device='cuda:0')
# 0057 = tensor([16], device='cuda:0')
# 0058 = tensor([16], device='cuda:0')
# 0059 = tensor([16], device='cuda:0')
# 0060 = tensor([17], device='cuda:0')
# 0061 = tensor([17], device='cuda:0')
# 0062 = tensor([18], device='cuda:0')
# 0063 = tensor([18], device='cuda:0')
# 0064 = tensor([19], device='cuda:0')
# 0065 = tensor([19], device='cuda:0')
# 0066 = tensor([19], device='cuda:0')
# 0067 = tensor([13], device='cuda:0')
# 0068 = tensor([20], device='cuda:0')
# 0069 = tensor([20], device='cuda:0')
# 0070 = tensor([20], device='cuda:0')
# 0071 = tensor([89], device='cuda:0')
# 0072 = tensor([21], device='cuda:0')
# 0073 = tensor([21], device='cuda:0')
# 0074 = tensor([21], device='cuda:0')
# 0075 = tensor([22], device='cuda:0')
# 0076 = tensor([22], device='cuda:0')
# 0077 = tensor([21], device='cuda:0')
# 0078 = tensor([980], device='cuda:0')
# 0079 = tensor([21], device='cuda:0')
# 0080 = tensor([372], device='cuda:0')
# 0081 = tensor([24], device='cuda:0')
# 0082 = tensor([24], device='cuda:0')
# 0083 = tensor([24], device='cuda:0')
# 0084 = tensor([24], device='cuda:0')
# 0085 = tensor([58], device='cuda:0')
# 0086 = tensor([25], device='cuda:0')
# 0087 = tensor([25], device='cuda:0')
# 0088 = tensor([27], device='cuda:0')
# 0089 = tensor([26], device='cuda:0')
# 0090 = tensor([26], device='cuda:0')
# 0091 = tensor([38], device='cuda:0')
# 0092 = tensor([27], device='cuda:0')
# 0093 = tensor([27], device='cuda:0')
# 0094 = tensor([26], device='cuda:0')
# 0095 = tensor([26], device='cuda:0')
# 0096 = tensor([28], device='cuda:0')
# 0097 = tensor([28], device='cuda:0')
# 0098 = tensor([71], device='cuda:0')
# 0099 = tensor([28], device='cuda:0')
# 0100 = tensor([29], device='cuda:0')
# 0101 = tensor([29], device='cuda:0')
# 0102 = tensor([30], device='cuda:0')
# 0103 = tensor([47], device='cuda:0')
# 0104 = tensor([30], device='cuda:0')
# 0105 = tensor([32], device='cuda:0')
# 0106 = tensor([31], device='cuda:0')
# 0107 = tensor([31], device='cuda:0')
# 0108 = tensor([31], device='cuda:0')
# ...
# 3645 = tensor([923], device='cuda:0')
# 3646 = tensor([996], device='cuda:0')
# 3647 = tensor([924], device='cuda:0')
# 3648 = tensor([924], device='cuda:0')
# 3649 = tensor([924], device='cuda:0')
# 3650 = tensor([925], device='cuda:0')
# 3651 = tensor([521], device='cuda:0')
# 3652 = tensor([809], device='cuda:0')
# 3653 = tensor([925], device='cuda:0')
# 3654 = tensor([926], device='cuda:0')
# 3655 = tensor([926], device='cuda:0')
# 3656 = tensor([926], device='cuda:0')
# 3657 = tensor([927], device='cuda:0')
# 3658 = tensor([927], device='cuda:0')
# 3659 = tensor([927], device='cuda:0')
# 3660 = tensor([927], device='cuda:0')
# 3661 = tensor([314], device='cuda:0')
# 3662 = tensor([928], device='cuda:0')
# 3663 = tensor([960], device='cuda:0')
# 3664 = tensor([928], device='cuda:0')
# 3665 = tensor([792], device='cuda:0')
# 3666 = tensor([929], device='cuda:0')
# 3667 = tensor([591], device='cuda:0')
# 3668 = tensor([433], device='cuda:0')
# 3669 = tensor([931], device='cuda:0')
# 3670 = tensor([934], device='cuda:0')
# 3671 = tensor([930], device='cuda:0')
# 3672 = tensor([931], device='cuda:0')
# 3673 = tensor([931], device='cuda:0')
# 3674 = tensor([923], device='cuda:0')
# 3675 = tensor([932], device='cuda:0')
# 3676 = tensor([932], device='cuda:0')
# 3677 = tensor([932], device='cuda:0')
# 3678 = tensor([934], device='cuda:0')
# 3679 = tensor([933], device='cuda:0')
# 3680 = tensor([933], device='cuda:0')
# 3681 = tensor([934], device='cuda:0')
# 3682 = tensor([934], device='cuda:0')
# 3683 = tensor([118], device='cuda:0')
# 3684 = tensor([935], device='cuda:0')
# 3685 = tensor([936], device='cuda:0')
# 3686 = tensor([936], device='cuda:0')
# 3687 = tensor([728], device='cuda:0')
# 3688 = tensor([936], device='cuda:0')
# 3689 = tensor([937], device='cuda:0')
# 3690 = tensor([938], device='cuda:0')
# 3691 = tensor([937], device='cuda:0')
# 3692 = tensor([937], device='cuda:0')
# 3693 = tensor([935], device='cuda:0')
# 3694 = tensor([938], device='cuda:0')
# 3695 = tensor([938], device='cuda:0')
# 3696 = tensor([938], device='cuda:0')
# 3697 = tensor([938], device='cuda:0')
# 3698 = tensor([939], device='cuda:0')
# 3699 = tensor([943], device='cuda:0')
# 3700 = tensor([929], device='cuda:0')
# 3701 = tensor([940], device='cuda:0')
# 3702 = tensor([940], device='cuda:0')
# 3703 = tensor([722], device='cuda:0')
# 3704 = tensor([961], device='cuda:0')
# 3705 = tensor([940], device='cuda:0')
# 3706 = tensor([941], device='cuda:0')
# 3707 = tensor([952], device='cuda:0')
# 3708 = tensor([940], device='cuda:0')
# 3709 = tensor([942], device='cuda:0')
# 3710 = tensor([942], device='cuda:0')
# 3711 = tensor([813], device='cuda:0')
# 3712 = tensor([942], device='cuda:0')
# 3713 = tensor([943], device='cuda:0')
# 3714 = tensor([883], device='cuda:0')
# 3715 = tensor([943], device='cuda:0')
# 3716 = tensor([939], device='cuda:0')
# 3717 = tensor([946], device='cuda:0')
# 3718 = tensor([968], device='cuda:0')
# 3719 = tensor([943], device='cuda:0')
# 3720 = tensor([944], device='cuda:0')
# 3721 = tensor([945], device='cuda:0')
# 3722 = tensor([945], device='cuda:0')
# 3723 = tensor([315], device='cuda:0')
# 3724 = tensor([509], device='cuda:0')
# 3725 = tensor([946], device='cuda:0')
# 3726 = tensor([946], device='cuda:0')
# 3727 = tensor([946], device='cuda:0')
# 3728 = tensor([947], device='cuda:0')
# 3729 = tensor([947], device='cuda:0')
# 3730 = tensor([948], device='cuda:0')
# 3731 = tensor([948], device='cuda:0')
# 3732 = tensor([948], device='cuda:0')
# 3733 = tensor([948], device='cuda:0')
# 3734 = tensor([948], device='cuda:0')
# 3735 = tensor([509], device='cuda:0')
# 3736 = tensor([948], device='cuda:0')
# 3737 = tensor([949], device='cuda:0')
# 3738 = tensor([793], device='cuda:0')
# 3739 = tensor([949], device='cuda:0')
# 3740 = tensor([949], device='cuda:0')
# 3741 = tensor([949], device='cuda:0')
# 3742 = tensor([599], device='cuda:0')
# 3743 = tensor([989], device='cuda:0')
# 3744 = tensor([951], device='cuda:0')
# 3745 = tensor([950], device='cuda:0')
# 3746 = tensor([951], device='cuda:0')
# 3747 = tensor([929], device='cuda:0')
# 3748 = tensor([951], device='cuda:0')
# 3749 = tensor([951], device='cuda:0')
# 3750 = tensor([952], device='cuda:0')
# 3751 = tensor([952], device='cuda:0')
# 3752 = tensor([952], device='cuda:0')
# 3753 = tensor([952], device='cuda:0')
# 3754 = tensor([953], device='cuda:0')
# 3755 = tensor([961], device='cuda:0')
# 3756 = tensor([389], device='cuda:0')
# 3757 = tensor([953], device='cuda:0')
# 3758 = tensor([954], device='cuda:0')
# 3759 = tensor([950], device='cuda:0')
# 3760 = tensor([954], device='cuda:0')
# 3761 = tensor([955], device='cuda:0')
# 3762 = tensor([938], device='cuda:0')
# 3763 = tensor([955], device='cuda:0')
# 3764 = tensor([956], device='cuda:0')
# 3765 = tensor([956], device='cuda:0')
# 3766 = tensor([956], device='cuda:0')
# 3767 = tensor([956], device='cuda:0')
# 3768 = tensor([956], device='cuda:0')
# 3769 = tensor([957], device='cuda:0')
# 3770 = tensor([957], device='cuda:0')
# 3771 = tensor([957], device='cuda:0')
# 3772 = tensor([957], device='cuda:0')
# 3773 = tensor([957], device='cuda:0')
# 3774 = tensor([112], device='cuda:0')
# 3775 = tensor([958], device='cuda:0')
# 3776 = tensor([958], device='cuda:0')
# 3777 = tensor([521], device='cuda:0')
# 3778 = tensor([922], device='cuda:0')
# 3779 = tensor([34], device='cuda:0')
# 3780 = tensor([940], device='cuda:0')
# 3781 = tensor([118], device='cuda:0')
# 3782 = tensor([6], device='cuda:0')
# 3783 = tensor([961], device='cuda:0')
# 3784 = tensor([935], device='cuda:0')
# 3785 = tensor([961], device='cuda:0')
# 3786 = tensor([959], device='cuda:0')
# 3787 = tensor([118], device='cuda:0')
# 3788 = tensor([935], device='cuda:0')
# 3789 = tensor([963], device='cuda:0')
# 3790 = tensor([963], device='cuda:0')
# 3791 = tensor([964], device='cuda:0')
# 3792 = tensor([964], device='cuda:0')
# 3793 = tensor([964], device='cuda:0')
# 3794 = tensor([926], device='cuda:0')
# 3795 = tensor([899], device='cuda:0')
# 3796 = tensor([959], device='cuda:0')
# 3797 = tensor([965], device='cuda:0')
# 3798 = tensor([515], device='cuda:0')
# 3799 = tensor([966], device='cuda:0')
# 3800 = tensor([572], device='cuda:0')
# 3801 = tensor([966], device='cuda:0')
# 3802 = tensor([572], device='cuda:0')
# 3803 = tensor([550], device='cuda:0')
# 3804 = tensor([967], device='cuda:0')
# 3805 = tensor([967], device='cuda:0')
# 3806 = tensor([659], device='cuda:0')
# 3807 = tensor([968], device='cuda:0')
# 3808 = tensor([504], device='cuda:0')
# 3809 = tensor([463], device='cuda:0')
# 3810 = tensor([925], device='cuda:0')
# 3811 = tensor([504], device='cuda:0')
# 3812 = tensor([969], device='cuda:0')
# 3813 = tensor([659], device='cuda:0')
# 3814 = tensor([969], device='cuda:0')
# 3815 = tensor([970], device='cuda:0')
# 3816 = tensor([970], device='cuda:0')
# 3817 = tensor([671], device='cuda:0')
# 3818 = tensor([971], device='cuda:0')
# 3819 = tensor([971], device='cuda:0')
# 3820 = tensor([971], device='cuda:0')
# 3821 = tensor([921], device='cuda:0')
# 3822 = tensor([873], device='cuda:0')
# 3823 = tensor([525], device='cuda:0')
# 3824 = tensor([979], device='cuda:0')
# 3825 = tensor([979], device='cuda:0')
# 3826 = tensor([973], device='cuda:0')
# 3827 = tensor([973], device='cuda:0')
# 3828 = tensor([974], device='cuda:0')
# 3829 = tensor([974], device='cuda:0')
# 3830 = tensor([974], device='cuda:0')
# 3831 = tensor([974], device='cuda:0')
# 3832 = tensor([975], device='cuda:0')
# 3833 = tensor([525], device='cuda:0')
# 3834 = tensor([975], device='cuda:0')
# 3835 = tensor([49], device='cuda:0')
# 3836 = tensor([718], device='cuda:0')
# 3837 = tensor([976], device='cuda:0')
# 3838 = tensor([296], device='cuda:0')
# 3839 = tensor([976], device='cuda:0')
# 3840 = tensor([144], device='cuda:0')
# 3841 = tensor([978], device='cuda:0')
# 3842 = tensor([977], device='cuda:0')
# 3843 = tensor([977], device='cuda:0')
# 3844 = tensor([273], device='cuda:0')
# 3845 = tensor([49], device='cuda:0')
# 3846 = tensor([649], device='cuda:0')
# 3847 = tensor([977], device='cuda:0')
# 3848 = tensor([979], device='cuda:0')
# 3849 = tensor([972], device='cuda:0')
# 3850 = tensor([979], device='cuda:0')
# 3851 = tensor([980], device='cuda:0')
# 3852 = tensor([716], device='cuda:0')
# 3853 = tensor([980], device='cuda:0')
# 3854 = tensor([980], device='cuda:0')
# 3855 = tensor([862], device='cuda:0')
# 3856 = tensor([981], device='cuda:0')
# 3857 = tensor([981], device='cuda:0')
# 3858 = tensor([415], device='cuda:0')
# 3859 = tensor([982], device='cuda:0')
# 3860 = tensor([513], device='cuda:0')
# 3861 = tensor([731], device='cuda:0')
# 3862 = tensor([983], device='cuda:0')
# 3863 = tensor([983], device='cuda:0')
# 3864 = tensor([983], device='cuda:0')
# 3865 = tensor([983], device='cuda:0')
# 3866 = tensor([984], device='cuda:0')
# 3867 = tensor([984], device='cuda:0')
# 3868 = tensor([984], device='cuda:0')
# 3869 = tensor([984], device='cuda:0')
# 3870 = tensor([984], device='cuda:0')
# 3871 = tensor([985], device='cuda:0')
# 3872 = tensor([985], device='cuda:0')
# 3873 = tensor([985], device='cuda:0')
# 3874 = tensor([985], device='cuda:0')
# 3875 = tensor([986], device='cuda:0')
# 3876 = tensor([986], device='cuda:0')
# 3877 = tensor([986], device='cuda:0')
# 3878 = tensor([986], device='cuda:0')
# 3879 = tensor([998], device='cuda:0')
# 3880 = tensor([858], device='cuda:0')
# 3881 = tensor([998], device='cuda:0')
# 3882 = tensor([988], device='cuda:0')
# 3883 = tensor([988], device='cuda:0')
# 3884 = tensor([968], device='cuda:0')
# 3885 = tensor([988], device='cuda:0')
# 3886 = tensor([989], device='cuda:0')
# 3887 = tensor([317], device='cuda:0')
# 3888 = tensor([989], device='cuda:0')
# 3889 = tensor([989], device='cuda:0')
# 3890 = tensor([990], device='cuda:0')
# 3891 = tensor([317], device='cuda:0')
# 3892 = tensor([990], device='cuda:0')
# 3893 = tensor([991], device='cuda:0')
# 3894 = tensor([991], device='cuda:0')
# 3895 = tensor([992], device='cuda:0')
# 3896 = tensor([992], device='cuda:0')
# 3897 = tensor([993], device='cuda:0')
# 3898 = tensor([993], device='cuda:0')
# 3899 = tensor([993], device='cuda:0')
# 3900 = tensor([994], device='cuda:0')
# 3901 = tensor([994], device='cuda:0')
# 3902 = tensor([994], device='cuda:0')
# 3903 = tensor([994], device='cuda:0')
# 3904 = tensor([995], device='cuda:0')
# 3905 = tensor([995], device='cuda:0')
# 3906 = tensor([995], device='cuda:0')
# 3907 = tensor([996], device='cuda:0')
# 3908 = tensor([996], device='cuda:0')
# 3909 = tensor([996], device='cuda:0')
# 3910 = tensor([997], device='cuda:0')
# 3911 = tensor([997], device='cuda:0')
# 3912 = tensor([997], device='cuda:0')
# 3913 = tensor([997], device='cuda:0')
# 3914 = tensor([947], device='cuda:0')
# 3915 = tensor([997], device='cuda:0')
# 3916 = tensor([599], device='cuda:0')
# 3917 = tensor([998], device='cuda:0')
# 3918 = tensor([999], device='cuda:0')
# 3919 = tensor([999], device='cuda:0')
# 3920 = tensor([904], device='cuda:0')
# 3921 = tensor([999], device='cuda:0')
# 3922 = tensor([999], device='cuda:0')
# model = resnet34
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
#  84%|████████▍ | 3294/3923 [00:41<00:07, 78.79it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [16], line 113
#     110     model.to('cpu')
#     112 with torch.no_grad():
# --> 113     output = model(input_batch)
#     115 # Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
#     116 #print(output[0])
#     117
#     118 # The output has unnormalized scores. To get probabilities, you can run a softmax on it.
#     119 probabilities = torch.nn.functional.softmax(output[0], dim=0)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File ~/.local/lib/python3.8/site-packages/torchvision/models/resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torchvision/models/resnet.py:93, in BasicBlock.forward(self, x)
#      90 identity = x
#      92 out = self.conv1(x)
# ---> 93 out = self.bn1(out)
#      94 out = self.relu(out)
#      96 out = self.conv2(out)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/batchnorm.py:168, in _BatchNorm.forward(self, input)
#     161     bn_training = (self.running_mean is None) and (self.running_var is None)
#     163 r"""
#     164 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     165 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     166 used for normalization (i.e. in eval mode when buffers are not None).
#     167 """
# --> 168 return F.batch_norm(
#     169     input,
#     170     # If buffers are not to be tracked, ensure that they won't be updated
#     171     self.running_mean
#     172     if not self.training or self.track_running_stats
#     173     else None,
#     174     self.running_var if not self.training or self.track_running_stats else None,
#     175     self.weight,
#     176     self.bias,
#     177     bn_training,
#     178     exponential_average_factor,
#     179     self.eps,
#     180 )
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/functional.py:2438, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2435 if training:
#    2436     _verify_batch_size(input.size())
# -> 2438 return torch.batch_norm(
#    2439     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2440 )
#
# KeyboardInterrupt:

# %%
int(top1_catids[111])
# Out:
# 71

# %% [markdown]
# ## CPU 동작모드

# %%
# sample execution (requires torchvision)
from PIL import Image
from torchvision import transforms
import time
from tqdm import tqdm
import numpy as np
import torch

'''
# Define transforms for the evaluation phase
preprocess = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                ])
'''

preproc = ['method1', 'method2']
preproc_method = 'method1'

devices = ['cuda', 'cpu']
devices = ['cpu']

models = []


testset = testfiles[:]
n = len(testset)

# 디바이스별 반복
for device in devices: 
    print('-'*50)
    print('device = ', device, flush=True)
    print('-'*50)
        
    # 모델별 반복
    for model_idx, model_name in enumerate(model_names):
        start = time.time() # strt timer        
        print(f'model = {model_names[model_idx]}', flush=True)
        
        # 모델 템플릿 다운로드 (from torch.hub)
        if model_name in model_names_resnet:
            model = torch.hub.load(repo_resnet, model_name, pretrained=False)
        elif model_name in model_names_mobnet:
            model = torch.hub.load(repo_mobnet, model_name, pretrained=False)
        elif model_name in model_names_effnet:
            model = torch.hub.load(repo_effnet, model_name, pretrained=False)
        else:
            pass
    
        # 모델 가중치 다운로드 (from AI 모델 리포지토리)
        if False:    
            # 방법 1
            pass
        
            # torch.hub.download_url_to_file(urlroot+pthnames[model_idx], modeldir+pthnames[model_idx])
            # model.load_state_dict(torch.hub.load_state_dict_from_url(checkpoint, progress=False))
            # model.eval()
        else:
            # 방법 2
            checkpoint = urlmodels[model_idx]
            model.load_state_dict(torch.hub.load_state_dict_from_url(checkpoint, progress=False))
            model.eval().to(device) # change model to evauation mode (e.g. disable Dropout, BatchNorm)
            models.append(model)
 
        # 시험용 입력 영상
        top1_cnt = 0
        top5_cnt = 0
              
        # 시험용 입력 영상 전처리 (크기 및 컬러채널)
        if preproc_method == preproc[0]:
            preprocess = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
            ])
        else:
            preprocess = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            ])

        # 시험영상별 반복
        imgidx = 0
        for fpath in tqdm( testset ):
        #for fpath in testset:
            #print( fpath )
            input_image = Image.open(fpath)

            try:
                input_tensor = preprocess(input_image)
            except:
                # gray scale to color
                input_image = Image.open(fpath).convert("RGB")
                input_tensor = preprocess(input_image)

            input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

            # 디바이스 설정
            if device == 'cuda':
                if torch.cuda.is_available():
                    input_batch = input_batch.to('cuda')
                    model.to('cuda')
            else:
                input_batch = input_batch.to('cpu')
                model.to('cpu')
              
            with torch.no_grad():
                output = model(input_batch)

            # Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
            #print(output[0])

            # The output has unnormalized scores. To get probabilities, you can run a softmax on it.
            probabilities = torch.nn.functional.softmax(output[0], dim=0)
            #print(probabilities)

            # Show top categories per image
            top5_prob, top5_catid = torch.topk(probabilities, 5)
            for i in range(top5_prob.size(0)):
                #print(top5_catid[i])
                #print(imgidx, ' ', categories[top5_catid[i]], top5_prob[i].item())

                if( top5_catid[i] == idx_gt[imgidx] ):
                    top1_cnt += 1

            imgidx += 1

        end = time.time() # end timer
        print('n = ', n)
        print('top1_cnt = ', top1_cnt)
        print('top1_cnt/n = ', top1_cnt/n)
        print('time = ', end - start)
        print('')
# Out:
# --------------------------------------------------
# device =  cpu
# --------------------------------------------------
# model = resnet18
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [01:55<00:00, 33.82it/s]
# n =  3923
# top1_cnt =  3358
# top1_cnt/n =  0.8559775681876115
# time =  116.17684650421143
#
# model = resnet34
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [03:01<00:00, 21.58it/s]
# n =  3923
# top1_cnt =  3476
# top1_cnt/n =  0.8860565893448891
# time =  182.05406522750854
#
# model = resnet50
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [03:44<00:00, 17.51it/s]
# n =  3923
# top1_cnt =  3545
# top1_cnt/n =  0.9036451695131277
# time =  224.42821073532104
#
# model = resnet101
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [06:06<00:00, 10.70it/s]
# n =  3923
# top1_cnt =  3572
# top1_cnt/n =  0.9105276574050472
# time =  367.11171436309814
#
# model = resnet152
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [08:18<00:00,  7.87it/s]
# n =  3923
# top1_cnt =  3584
# top1_cnt/n =  0.9135865409125669
# time =  499.18171405792236
#
# model = nvidia_efficientnet_b0
# Using cache found in /home/jpark/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# 100%|██████████| 3923/3923 [01:52<00:00, 34.95it/s]
# n =  3923
# top1_cnt =  3619
# top1_cnt/n =  0.9225082844761662
# time =  112.36311888694763
#
# model = nvidia_efficientnet_b4
# Using cache found in /home/jpark/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# 100%|██████████| 3923/3923 [03:55<00:00, 16.63it/s]
# n =  3923
# top1_cnt =  3550
# top1_cnt/n =  0.9049197043079276
# time =  236.33543014526367
#
# model = nvidia_efficientnet_widese_b0
# Using cache found in /home/jpark/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# 100%|██████████| 3923/3923 [01:52<00:00, 34.74it/s]
# n =  3923
# top1_cnt =  3633
# top1_cnt/n =  0.9260769819016059
# time =  113.0606951713562
#
# model = nvidia_efficientnet_widese_b4
# Using cache found in /home/jpark/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# 100%|██████████| 3923/3923 [04:01<00:00, 16.24it/s]
# n =  3923
# top1_cnt =  3516
# top1_cnt/n =  0.8962528677032883
# time =  242.02179408073425
#
# model = mobilenet_v3_small
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [00:59<00:00, 66.34it/s]
# n =  3923
# top1_cnt =  3353
# top1_cnt/n =  0.8547030333928116
# time =  59.20183300971985
#
# model = mobilenet_v3_large
# Using cache found in /home/jpark/.cache/torch/hub/pytorch_vision_v0.10.0
# 100%|██████████| 3923/3923 [01:24<00:00, 46.66it/s]
# n =  3923
# top1_cnt =  3556
# top1_cnt/n =  0.9064491460616875
# time =  84.20090246200562
