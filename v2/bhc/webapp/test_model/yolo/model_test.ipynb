# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
def load_model(model_name):

    model = torch.hub.load('ultralytics/yolov5', model_name, pretrained=True)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    return model


def get_pred(model_name, input):

    model = load_model(model_name)
    img = input

    result = model(img)

    return result

# %%
if __name__ == '__main__':

    input_path = 'data/test.jpg'

    pred = get_pred('yolov5l', input_path)

    pred.print()
    pred.show()
# Out:
# Using cache found in /home/keti/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-3-3 Python-3.8.15 torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 12044MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l.pt to yolov5l.pt...
#   0%|          | 0.00/89.3M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5l summary: 367 layers, 46533693 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 183x275 1 person, 1 dog
# Speed: 2.1ms pre-process, 33.9ms inference, 1.4ms NMS per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=275x183>
